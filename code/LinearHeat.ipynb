# %%
# Alex Domagala
# ECE 6560

import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
from matplotlib import animation
import os
import glob
from matplotlib import cm

img = Image.open('../images/butterfly.png')
img = np.array(img)
img = img[:,:,0]
print(img.shape)
noise = 5*np.random.randn(img.shape[0],img.shape[1]) # standard normal distribution
print(noise.shape)
plt.imshow(img,cmap='gray')
plt.show()
img = img + noise
plt.imshow(img, cmap='gray')
plt.show()
# Out:
# (256, 256)
# (256, 256)

# %%
def linearHeat(I):
  frames = []
  Inew = I
  #frames.append(Inew)

  # iterate through all the pixels in the image
  for k in range(150):
    for i in range(1,I.shape[0]-1):
      for j in range(1,I.shape[1]-1):
        #print(str(i) + ' ' + str(j))
        Inew[i,j] = Inew[i,j] + 0.1*((Inew[i+1,j] - 2*Inew[i,j] + Inew[i-1,j]) + (Inew[i,j+1] - 2*Inew[i,j] + Inew[i,j-1]))
        #frames.append(Inew)
    if (k % 10 == 0):
      print(k)
      plt.imshow(Inew,cmap='gray')
      plt.show()
  #return frames

print(img.shape)
newFrames = linearHeat(img)
#plt.imshow(new, cmap='gray')
# Out:
# (256, 256)
# 0
# 10
# 20
# 30
# 40
# 50
# 60
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 20
#      17   #return frames
#      19 print(img.shape)
# ---> 20 newFrames = linearHeat(img)
#      21 #plt.imshow(new, cmap='gray')
#
# Cell In[13], line 11, in linearHeat(I)
#       8 for i in range(1,I.shape[0]-1):
#       9   for j in range(1,I.shape[1]-1):
#      10     #print(str(i) + ' ' + str(j))
# ---> 11     Inew[i,j] = Inew[i,j] + 0.1*((Inew[i+1,j] - 2*Inew[i,j] + Inew[i-1,j]) + (Inew[i,j+1] - 2*Inew[i,j] + Inew[i,j-1]))
#      12     #frames.append(Inew)
#      13 if (k % 10 == 0):
#
# KeyboardInterrupt:
